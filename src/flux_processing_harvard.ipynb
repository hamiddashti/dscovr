# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import zscore, linregress
import glob as glob

# %%
ec = pd.read_csv(
    "../data/EC/AMF_US-Ha1_FLUXNET_SUBSET_1991-2020_3-5/AMF_US-Ha1_FLUXNET_SUBSET_WW_1991-2020_3-5.csv"
)
ec["t1"] = pd.to_datetime(ec["TIMESTAMP_START"], format="%Y%m%d")
ec["t2"] = pd.to_datetime(ec["TIMESTAMP_END"], format="%Y%m%d")
ec
# Out:
#       TIMESTAMP_START  TIMESTAMP_END   TA_F  TA_F_QC  SW_IN_POT  SW_IN_F  \
# 0            19910101       19910107 -3.393      0.0    144.712   78.307
# 1            19910108       19910114 -7.811      0.0    151.539   66.690
# 2            19910115       19910121 -1.479      0.0    161.127   76.578
# 3            19910122       19910128 -8.737      0.0    173.311  109.883
# 4            19910129       19910204  0.114      0.0    187.865  110.470
# ...               ...            ...    ...      ...        ...      ...
# 1555         20201125       20201201  7.188      1.0    155.133   46.687
# 1556         20201202       20201208  0.066      1.0    147.219   58.970
# 1557         20201209       20201215  0.714      1.0    142.072   52.697
# 1558         20201216       20201222 -4.340      1.0    139.788   59.078
# 1559         20201223       20201231  1.203      1.0    140.827   55.434
#
#       SW_IN_F_QC  LW_IN_F  LW_IN_F_QC  VPD_F  ...  RECO_DT_VUT_50  \
# 0            0.0  227.069         0.0  1.498  ...        0.342643
# 1            0.0  239.126         0.0  0.766  ...        0.270266
# 2            0.0  254.182         0.0  1.263  ...        0.376712
# 3            0.0  194.990         0.0  1.114  ...        0.258281
# 4            0.0  240.370         0.0  2.323  ...        0.412481
# ...          ...      ...         ...    ...  ...             ...
# 1555         1.0  301.488         0.0  1.682  ...        1.699480
# 1556         1.0  249.962         0.0  1.943  ...        0.838026
# 1557         1.0  260.636         0.0  1.415  ...        0.803554
# 1558         1.0  239.781         0.0  0.916  ...        0.549187
# 1559         1.0  259.134         0.0  1.922  ...        0.837961
#
#       RECO_DT_VUT_75  GPP_DT_VUT_REF  GPP_DT_VUT_25  GPP_DT_VUT_50  \
# 0           0.972297        0.576388       0.338614       0.379458
# 1           0.816256        0.495106       0.288445       0.323465
# 2           1.031730        0.559202       0.330911       0.370255
# 3           0.781874        0.740832       0.472714       0.521428
# 4           1.070000        0.740723       0.475033       0.523175
# ...              ...             ...            ...            ...
# 1555        1.769380        0.370576       0.285887       0.346777
# 1556        0.869736        0.398941       0.373451       0.386555
# 1557        0.849397        0.300488       0.287912       0.300488
# 1558        0.568441        0.087133       0.087116       0.087133
# 1559        0.876614        0.153897       0.140201       0.153897
#
#       GPP_DT_VUT_75  RECO_SR  RECO_SR_N         t1         t2
# 0          0.576388    -9999      -9999 1991-01-01 1991-01-07
# 1          0.495106    -9999      -9999 1991-01-08 1991-01-14
# 2          0.559202    -9999      -9999 1991-01-15 1991-01-21
# 3          0.740832    -9999      -9999 1991-01-22 1991-01-28
# 4          0.740723    -9999      -9999 1991-01-29 1991-02-04
# ...             ...      ...        ...        ...        ...
# 1555       0.352086    -9999      -9999 2020-11-25 2020-12-01
# 1556       0.398941    -9999      -9999 2020-12-02 2020-12-08
# 1557       0.300525    -9999      -9999 2020-12-09 2020-12-15
# 1558       0.090111    -9999      -9999 2020-12-16 2020-12-22
# 1559       0.164299    -9999      -9999 2020-12-23 2020-12-31
#
# [1560 rows x 74 columns]

# %%
refl_fluxnet = glob.glob(
    "../data/EC/Ameriflux/sat_data/*batch" + str(i) + "*MCD43A4-061-results.csv"
)
